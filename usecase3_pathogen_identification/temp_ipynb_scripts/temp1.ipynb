# %%
## Import standard libraries
import os
import sys
from tqdm import tqdm, trange
from glob import glob
import pandas as pd
import random
import logging
import argparse

## Import custom libraries
sys.path.append('/scratch/shared_data_new/metagenomics_graph/model_training/scripts')
from utils import get_logger, read_tsv_file, set_seed

# %%
class Args():
    pass

args = Args()


args.existing_KG_nodes = '/scratch/shared_data_new/metagenomics_graph/KG/KG_nodes_v6.tsv'
args.existing_KG_edges = '/scratch/shared_data_new/metagenomics_graph/KG/KG_edges_v6.tsv'
args.micobial_hierarchy_dir = '/scratch/shared_data_new/metagenomics_graph/Micobial_hierarchy'
args.output_dir = '/scratch/shared_data_new/metagenomics_graph/model_training/data'
args.random_seed = 100

# %%
def find_specific_parent(microbe_id, ranks, microbe_info, find_parent):
    """
    Find the specific parent of a microbe
    """
    
    def _recursive_find_parent(microbe_id, ranks, microbe_info, find_parent, res, count=0):
        """
        iterate all the way up to the top of the hierarchy and find all parents belong to the specific ranks
        """
        if count == 8:
            return res
        
        count += 1
        if microbe_id not in find_parent:
            return res
        elif len(microbe_info[microbe_id][0].intersection(set(ranks))) > 0:
            res += [microbe_id]
            return _recursive_find_parent(find_parent[microbe_id], ranks, microbe_info, find_parent, res, count)
        else:
            return _recursive_find_parent(find_parent[microbe_id], ranks, microbe_info, find_parent, res, count)
    
    res = _recursive_find_parent(microbe_id, ranks, microbe_info, find_parent, [], 0)
    if len(res) == 0:
        return [microbe_id]
    else:
        return res + [microbe_id]

def check_parent(microbe_id, excluded_microbe_ids, find_parent, count=0):
    """
    Check if the parent of a microbe is in the excluded microbe ids
    """
    if count == 8:
        return True
    
    if microbe_id in excluded_microbe_ids:
        return False
    
    if microbe_id not in find_parent:
        return True
    else:
        count += 1
        return check_parent(find_parent[microbe_id], excluded_microbe_ids, find_parent, count)

def extract_info(sysnonyms, microbe_info_dict, find_parent):
    """
    Get the rank and parent of a microbe based on its id
    """
    if isinstance(sysnonyms, str):
        sysnonyms = eval(sysnonyms)

    rank_list = []
    taxon_id_list = []
    parent_list = []
    for synonym in sysnonyms:
        prefix = synonym.split(':')[0]
        if prefix not in ['NCBI', 'GTDB']:
            continue
        if synonym not in microbe_info_dict:
            continue
        rank_list += list(microbe_info_dict[synonym][0])
        taxon_id_list += list(microbe_info_dict[synonym][1])
        parent_list.append(find_parent[synonym])

    parent_rank_list = []
    parent_taxon_id_list = []
    for parent in parent_list:
        parent_rank_list += list(microbe_info_dict[parent][0])
        parent_taxon_id_list += list(microbe_info_dict[parent][1])
    
    sysnonyms = str(sysnonyms)
    rank_list = str(rank_list)
    taxon_id_list = str(taxon_id_list)
    parent_list = str(parent_list)
    parent_rank_list = str(parent_rank_list)
    parent_taxon_id_list = str(parent_taxon_id_list)
    
    return sysnonyms, rank_list, taxon_id_list, parent_list, parent_rank_list, parent_taxon_id_list

# %%
# Create a logger object
logger = get_logger()
logger.setLevel(logging.DEBUG)

# set the seed for reproducibility
set_seed(args.random_seed)

# Load existing knowledge graph nodes and edges
logger.info("Loading existing knowledge graph nodes and edges...")
KG_nodes_data = read_tsv_file(args.existing_KG_nodes)
KG_nodes_header = KG_nodes_data[0]
KG_edges_data = read_tsv_file(args.existing_KG_edges)
KG_edges_header = KG_edges_data[0]
# Out:
# 2024-01-10 11:52:21  [INFO]  Loading existing knowledge graph nodes and edges...

# %%
# Load microbial hierarchy data
find_parent = dict()
find_child = dict()
microbe_info_dict = dict()
microbial_hierarchy_files = os.listdir(args.micobial_hierarchy_dir)
for microbial_hierarchy_file in tqdm(microbial_hierarchy_files, desc='Reading microbial hierarchy files'):
    if microbial_hierarchy_file.split('_')[0] in ['viruses', 'fungi']:
        prefix = 'NCBI:'
    else:
        prefix = 'GTDB:'
    microbial_hierarchy_file_path = os.path.join(args.micobial_hierarchy_dir, microbial_hierarchy_file)
    logger.info("Reading {}...".format(microbial_hierarchy_file_path))
    temp_data = read_tsv_file(microbial_hierarchy_file_path)
    for row in temp_data[1:]:
        row[0] = row[0].replace('GB_', '').replace('RS_', '')
        row[3] = row[3].replace('GB_', '').replace('RS_', '')
        if f"{prefix}{row[0]}" not in microbe_info_dict:
            microbe_info_dict[f"{prefix}{row[0]}"] = [set(), set()]
        microbe_info_dict[f"{prefix}{row[0]}"][0].add(row[1])
        microbe_info_dict[f"{prefix}{row[0]}"][1].add(row[2])              
        if f"{prefix}{row[3]}" not in microbe_info_dict:
            microbe_info_dict[f"{prefix}{row[3]}"] = [set(), set()]
        microbe_info_dict[f"{prefix}{row[3]}"][0].add(row[4])
        microbe_info_dict[f"{prefix}{row[3]}"][1].add(row[5])
        if f"{prefix}{row[3]}" != f"{prefix}{row[0]}":
            find_parent[f"{prefix}{row[3]}"] = f"{prefix}{row[0]}"
            if f"{prefix}{row[0]}" not in find_child:
                find_child[f"{prefix}{row[0]}"] = set()
            find_child[f"{prefix}{row[0]}"].add(f"{prefix}{row[3]}")

## Extract data from MKG for GNN model training 
logger.info("Extracting MKG for GNN model training...")
node_info = pd.DataFrame([(row[KG_nodes_header.index('node_id')], row[KG_nodes_header.index('node_type')], \
                            row[KG_nodes_header.index('all_names')], row[KG_nodes_header.index('synonyms')], row[KG_nodes_header.index('is_pathogen')]) \
                            for row in KG_nodes_data[1:]])
node_info.columns = ['node_id', 'node_type', 'all_names', 'synonyms', 'is_pathogen']
edge_info = pd.DataFrame([(row[KG_edges_header.index('source_node')], row[KG_edges_header.index('target_node')], row[KG_edges_header.index('predicate')]) for row in KG_edges_data[1:]])
edge_info.columns = ['source_node', 'target_node', 'predicate']

# Filter out the microbe-disease edges
edge_info_temp = []
filtered_type = ['Microbe', 'Disease']
for row in tqdm(edge_info.to_numpy(), desc="Filtering out the microbe-disease edges"):
    source_node, target_node, predicate = row
    source_type = source_node.split(':')[0]
    target_type = target_node.split(':')[0]
    if source_type == target_type:
        edge_info_temp.append(row)
    else:
        if source_type in filtered_type and target_type in filtered_type:
            continue
        else:
            edge_info_temp.append(row)
edge_info = pd.DataFrame(edge_info_temp)
edge_info.columns = ['source_node', 'target_node', 'predicate']
# Out:
# Reading microbial hierarchy files:   0%|          | 0/4 [00:00<?, ?it/s]
# 2024-01-10 11:53:42  [INFO]  Reading /scratch/shared_data_new/metagenomics_graph/Micobial_hierarchy/viruses_hierarchy.tsv...
# Reading microbial hierarchy files:  25%|██▌       | 1/4 [00:00<00:02,  1.11it/s]
# 2024-01-10 11:53:43  [INFO]  Reading /scratch/shared_data_new/metagenomics_graph/Micobial_hierarchy/fungi_hierarchy.tsv...
# Reading microbial hierarchy files:  50%|█████     | 2/4 [00:10<00:11,  5.95s/it]
# 2024-01-10 11:53:52  [INFO]  Reading /scratch/shared_data_new/metagenomics_graph/Micobial_hierarchy/bacteria_hierarchy.tsv...
# Reading microbial hierarchy files:  75%|███████▌  | 3/4 [00:12<00:04,  4.16s/it]
# 2024-01-10 11:53:54  [INFO]  Reading /scratch/shared_data_new/metagenomics_graph/Micobial_hierarchy/archaea_hierarchy.tsv...
# Reading microbial hierarchy files: 100%|██████████| 4/4 [00:12<00:00,  3.13s/it]
# 2024-01-10 11:53:54  [INFO]  Extracting MKG for GNN model training...
# Filtering out the microbe-disease edges: 100%|██████████| 46218489/46218489 [00:58<00:00, 790896.98it/s]

# %%
## Covert node and edge to index
# save node to index mapping
all_nodes = node_info['node_id'].to_list()
random.shuffle(all_nodes)
node_to_index = pd.DataFrame(all_nodes).reset_index()[[0, 'index']]
node_to_index.columns = ['node_id', 'node_index']
node_to_index.to_csv(os.path.join(args.output_dir, 'node_to_index.tsv'), sep='\t', index=False)
node_info.to_csv(os.path.join(args.output_dir, 'node_info.tsv'), sep='\t', index=False)

# %%
# save pathogen info
pathogen_info = node_info.loc[node_info['is_pathogen']=='True', :].reset_index(drop=True)
# find pathogen rank and its parent info
part1 = pathogen_info[['node_id', 'node_type', 'all_names', 'is_pathogen']]
part2 = pd.DataFrame(pathogen_info['synonyms'].apply(lambda x: extract_info(x, microbe_info_dict, find_parent)).to_list(), columns=['synonyms', 'rank_list', 'taxon_id_list', 'parent_list', 'parent_rank_list', 'parent_taxon_id_list'])
pathogen_info = pd.concat([part1, part2], axis=1)
pathogen_info = pathogen_info.loc[pathogen_info['synonyms'].str.contains('GTDB'),:].reset_index(drop=True)
pathogen_info = pathogen_info.loc[pathogen_info['rank_list'].str.contains('species|strain'),:].reset_index(drop=True)
pathogen_info.to_csv(os.path.join(args.output_dir, 'pathogen_info.tsv'), sep='\t', index=False)

# %%
# find all potential pathogens (all strains under the known species-level pathogens that have at least one pathogen or themself are known as pathogens )
species1 = set(pathogen_info.loc[pathogen_info['rank_list'].str.contains('strain'),'parent_list'].to_list())
species2 = set(pathogen_info.loc[pathogen_info['rank_list'].str.contains('species'),'synonyms'].to_list())
merged_species = species1 | species2
all_potential_pathogenic_strain = set()
for species in tqdm(merged_species):
    species_synonyms_list = eval(species)
    for species_synonyms in species_synonyms_list:
        all_potential_pathogenic_strain |= find_child[species_synonyms]
microbe_nodes = node_info.loc[node_info['node_id'].str.contains('Microbe'), :].reset_index(drop=True)
all_gtdb_id_to_microbe_id = dict()
for row in tqdm(microbe_nodes.to_numpy()):
    node_id, node_type, all_names, synonyms, is_pathogen = row
    if 'GTDB:' not in synonyms:
        continue
    all_gtdb_id_to_microbe_id
    synonyms = eval(synonyms)
    for synonym in synonyms:
        if 'GTDB:' in synonym:
            all_gtdb_id_to_microbe_id[synonym] = (synonym, node_id, node_type, all_names, synonyms, is_pathogen)
# Out:
# 100%|██████████| 708/708 [00:00<00:00, 28418.81it/s]
# 100%|██████████| 951782/951782 [00:03<00:00, 304568.22it/s]

# %%
all_gtdb_id_to_microbe_id = dict()
for row in tqdm(node_info.to_numpy()):
    node_id, node_type, all_names, synonyms, is_pathogen = row
    if 'GTDB:' not in synonyms:
        continue
    all_gtdb_id_to_microbe_id
    synonyms = eval(synonyms)
    for synonym in synonyms:
        if 'GTDB:' in synonym:
            all_gtdb_id_to_microbe_id[synonym] = (synonym, node_id, node_type, all_names, is_pathogen, synonyms)

# %%
gtdbid_df = pd.DataFrame(all_gtdb_id_to_microbe_id.values(), columns=['gtdb_id', 'node_id', 'node_type', 'all_names', 'is_pathogen', 'synonyms'])
# Out:
#   0%|          | 0/951782 [00:00<?, ?it/s]
# 100%|██████████| 951782/951782 [00:03<00:00, 254570.53it/s]

# %%
len(merged_species)
# Out:
# 708

# %%
gtdbid_df = pd.DataFrame(all_gtdb_id_to_microbe_id.values(), columns=['gtdb_id', 'node_id', 'node_type', 'all_names', 'synonyms', 'is_pathogen'])
gtdbid_df
# Out:
#                          gtdb_id         node_id              node_type  \
# 0                  GTDB:Bacteria  Microbe:431882  biolink:OrganismTaxon
# 1            GTDB:Pseudomonadota  Microbe:431883  biolink:OrganismTaxon
# 2       GTDB:Gammaproteobacteria  Microbe:431884  biolink:OrganismTaxon
# 3          GTDB:Enterobacterales  Microbe:431885  biolink:OrganismTaxon
# 4        GTDB:Enterobacteriaceae  Microbe:431886  biolink:OrganismTaxon
# ...                          ...             ...                    ...
# 510674      GTDB:GCA_000180295.1  Microbe:944250  biolink:OrganismTaxon
# 510675      GTDB:GCA_000268065.1  Microbe:944788  biolink:OrganismTaxon
# 510676      GTDB:GCA_000017125.1  Microbe:945749  biolink:OrganismTaxon
# 510677      GTDB:GCA_002249745.1  Microbe:945750  biolink:OrganismTaxon
# 510678      GTDB:GCA_000305735.1  Microbe:951782  biolink:OrganismTaxon
#
#                                                 all_names  \
# 0                                            ['Bacteria']
# 1                                      ['Pseudomonadota']
# 2                                 ['Gammaproteobacteria']
# 3                                    ['Enterobacterales']
# 4                                  ['Enterobacteriaceae']
# ...                                                   ...
# 510674  ['Salmonella enterica subsp. enterica serovar ...
# 510675                      ['Shigella flexneri 1235-66']
# 510676        ['Staphylococcus aureus subsp. aureus JH1']
# 510677                 ['Streptococcus pneumoniae B1598']
# 510678                             ['Vibrio sp. HENC-02']
#
#                                           synonyms is_pathogen
# 0                                  [GTDB:Bacteria]       False
# 1                            [GTDB:Pseudomonadota]        True
# 2                       [GTDB:Gammaproteobacteria]        True
# 3                          [GTDB:Enterobacterales]       False
# 4                        [GTDB:Enterobacteriaceae]        True
# ...                                            ...         ...
# 510674   [BVBRC:gn_496068.3, GTDB:GCA_000180295.1]        True
# 510675   [BVBRC:gn_766154.3, GTDB:GCA_000268065.1]        True
# 510676  [BVBRC:gn_359787.11, GTDB:GCA_000017125.1]        True
# 510677  [BVBRC:gn_1449970.3, GTDB:GCA_002249745.1]        True
# 510678   [GTDB:GCA_000305735.1, BVBRC:gn_992011.3]        True
#
# [510679 rows x 6 columns]

# %%
len(gtdbid_df['node_id'].unique())
# Out:
# 402732

# %%
gtdbid_df = pd.DataFrame(all_gtdb_id_to_microbe_id.values(), columns=['gtdb_id', 'node_id', 'node_type', 'all_names', 'synonyms', 'is_pathogen'])

# %%
gtdbid_df
# Out:
#                          gtdb_id         node_id              node_type  \
# 0                  GTDB:Bacteria  Microbe:431882  biolink:OrganismTaxon
# 1            GTDB:Pseudomonadota  Microbe:431883  biolink:OrganismTaxon
# 2       GTDB:Gammaproteobacteria  Microbe:431884  biolink:OrganismTaxon
# 3          GTDB:Enterobacterales  Microbe:431885  biolink:OrganismTaxon
# 4        GTDB:Enterobacteriaceae  Microbe:431886  biolink:OrganismTaxon
# ...                          ...             ...                    ...
# 510674      GTDB:GCA_000180295.1  Microbe:944250  biolink:OrganismTaxon
# 510675      GTDB:GCA_000268065.1  Microbe:944788  biolink:OrganismTaxon
# 510676      GTDB:GCA_000017125.1  Microbe:945749  biolink:OrganismTaxon
# 510677      GTDB:GCA_002249745.1  Microbe:945750  biolink:OrganismTaxon
# 510678      GTDB:GCA_000305735.1  Microbe:951782  biolink:OrganismTaxon
#
#                                                 all_names  \
# 0                                            ['Bacteria']
# 1                                      ['Pseudomonadota']
# 2                                 ['Gammaproteobacteria']
# 3                                    ['Enterobacterales']
# 4                                  ['Enterobacteriaceae']
# ...                                                   ...
# 510674  ['Salmonella enterica subsp. enterica serovar ...
# 510675                      ['Shigella flexneri 1235-66']
# 510676        ['Staphylococcus aureus subsp. aureus JH1']
# 510677                 ['Streptococcus pneumoniae B1598']
# 510678                             ['Vibrio sp. HENC-02']
#
#                                           synonyms is_pathogen
# 0                                  [GTDB:Bacteria]       False
# 1                            [GTDB:Pseudomonadota]        True
# 2                       [GTDB:Gammaproteobacteria]        True
# 3                          [GTDB:Enterobacterales]       False
# 4                        [GTDB:Enterobacteriaceae]        True
# ...                                            ...         ...
# 510674   [BVBRC:gn_496068.3, GTDB:GCA_000180295.1]        True
# 510675   [BVBRC:gn_766154.3, GTDB:GCA_000268065.1]        True
# 510676  [BVBRC:gn_359787.11, GTDB:GCA_000017125.1]        True
# 510677  [BVBRC:gn_1449970.3, GTDB:GCA_002249745.1]        True
# 510678   [GTDB:GCA_000305735.1, BVBRC:gn_992011.3]        True
#
# [510679 rows x 6 columns]

# %%
all_potential_pathogenic_strain_df = gtdbid_df.loc[gtdbid_df['gtdb_id'].isin(all_potential_pathogenic_strain),:].reset_index(drop=True)

# %%
all_potential_pathogenic_strain_df.to_csv(os.path.join(args.output_dir, 'all_potential_pathogenic_strain.tsv'), sep='\t', index=False)

# %%
species1
# Out:
# {"['GTDB:Achromobacter insolitus']",
#  "['GTDB:Achromobacter ruhlandii']",
#  "['GTDB:Achromobacter spanius']",
#  "['GTDB:Achromobacter xylosoxidans']",
#  "['GTDB:Acidaminococcus intestini']",
#  "['GTDB:Acinetobacter baumannii']",
#  "['GTDB:Acinetobacter calcoaceticus']",
#  "['GTDB:Acinetobacter fasciculus']",
#  "['GTDB:Acinetobacter haemolyticus']",
#  "['GTDB:Acinetobacter johnsonii']",
#  "['GTDB:Acinetobacter junii']",
#  "['GTDB:Acinetobacter radioresistens']",
#  "['GTDB:Acinetobacter schindleri']",
#  "['GTDB:Actinomyces oris']",
#  "['GTDB:Actinotignum schaalii']",
#  "['GTDB:Aerococcus christensenii']",
#  "['GTDB:Aerococcus sanguinicola']",
#  "['GTDB:Aerococcus urinae']",
#  "['GTDB:Aerococcus urinaehominis']",
#  "['GTDB:Aeromonas caviae']",
#  "['GTDB:Aeromonas enteropelogenes']",
#  "['GTDB:Aeromonas hydrophila']",
#  "['GTDB:Aggregatibacter actinomycetemcomitans']",
#  "['GTDB:Aggregatibacter actinomycetemcomitans_A']",
#  "['GTDB:Aggregatibacter aphrophilus']",
#  "['GTDB:Aliarcobacter butzleri']",
#  "['GTDB:Alistipes putredinis']",
#  "['GTDB:Alloiococcus otitis']",
#  "['GTDB:Anaplasma phagocytophilum']",
#  "['GTDB:Bacillus_A anthracis']",
#  "['GTDB:Bacillus_A cereus']",
#  "['GTDB:Bacillus_A cytotoxicus']",
#  "['GTDB:Bacillus_A mycoides']",
#  "['GTDB:Bacillus_A nitratireducens']",
#  "['GTDB:Bacillus_A paranthracis']",
#  "['GTDB:Bacillus_A thuringiensis_S']",
#  "['GTDB:Bacillus_A tropicus']",
#  "['GTDB:Bacteroides caccae']",
#  "['GTDB:Bacteroides fragilis']",
#  "['GTDB:Bartonella ancashensis']",
#  "['GTDB:Bartonella bacilliformis']",
#  "['GTDB:Bartonella grahamii']",
#  "['GTDB:Bartonella henselae']",
#  "['GTDB:Bartonella quintana']",
#  "['GTDB:Bergeyella_A cardium']",
#  "['GTDB:Bifidobacterium animalis']",
#  "['GTDB:Bifidobacterium leopoldii']",
#  "['GTDB:Bifidobacterium piotii']",
#  "['GTDB:Bifidobacterium vaginale']",
#  "['GTDB:Bifidobacterium vaginale_C']",
#  "['GTDB:Bifidobacterium vaginale_E']",
#  "['GTDB:Bordetella hinzii']",
#  "['GTDB:Bordetella holmesii']",
#  "['GTDB:Bordetella pertussis']",
#  "['GTDB:Bordetella_A petrii']",
#  "['GTDB:Bordetella_C bronchialis']",
#  "['GTDB:Bordetella_C flabilis']",
#  "['GTDB:Bordetella_C sp001704295']",
#  "['GTDB:Borrelia coriaceae']",
#  "['GTDB:Borrelia hermsii']",
#  "['GTDB:Borrelia miyamotoi']",
#  "['GTDB:Borrelia recurrentis']",
#  "['GTDB:Borrelia turicatae']",
#  "['GTDB:Borreliella afzelii']",
#  "['GTDB:Borreliella bissettiae']",
#  "['GTDB:Borreliella burgdorferi']",
#  "['GTDB:Borreliella garinii']",
#  "['GTDB:Borreliella mayonii']",
#  "['GTDB:Brachyspira pilosicoli']",
#  "['GTDB:Bradyrhizobium sp003020075']",
#  "['GTDB:Brucella melitensis']",
#  "['GTDB:Burkholderia ambifaria']",
#  "['GTDB:Burkholderia cenocepacia']",
#  "['GTDB:Burkholderia glumae']",
#  "['GTDB:Burkholderia mallei']",
#  "['GTDB:Burkholderia multivorans']",
#  "['GTDB:Burkholderia orbicola']",
#  "['GTDB:Burkholderia stabilis']",
#  "['GTDB:Campylobacter fetus']",
#  "['GTDB:Campylobacter_A concisus_A']",
#  "['GTDB:Campylobacter_A concisus_AB']",
#  "['GTDB:Campylobacter_A concisus_R']",
#  "['GTDB:Campylobacter_A curvus']",
#  "['GTDB:Campylobacter_A rectus']",
#  "['GTDB:Campylobacter_A showae']",
#  "['GTDB:Campylobacter_B ureolyticus']",
#  "['GTDB:Campylobacter_D coli']",
#  "['GTDB:Campylobacter_D jejuni']",
#  "['GTDB:Campylobacter_D upsaliensis']",
#  "['GTDB:Capnocytophaga canimorsus']",
#  "['GTDB:Capnocytophaga gingivalis']",
#  "['GTDB:Capnocytophaga ochracea']",
#  "['GTDB:Capnocytophaga sputigena']",
#  "['GTDB:Cedecea neteri_C']",
#  "['GTDB:Chlamydia trachomatis']",
#  "['GTDB:Chlamydophila pneumoniae']",
#  "['GTDB:Chlamydophila psittaci']",
#  "['GTDB:Chromobacterium violaceum']",
#  "['GTDB:Citrobacter_B koseri']",
#  "['GTDB:Clostridioides difficile']",
#  "['GTDB:Clostridium botulinum_A']",
#  "['GTDB:Clostridium_F botulinum']",
#  "['GTDB:Clostridium_G tetani']",
#  "['GTDB:Clostridium_H haemolyticum']",
#  "['GTDB:Clostridium_Q saccharolyticum_A']",
#  "['GTDB:Cohnella cholangitidis']",
#  "['GTDB:Corynebacterium amycolatum_A']",
#  "['GTDB:Corynebacterium argentoratense']",
#  "['GTDB:Corynebacterium aurimucosum_F']",
#  "['GTDB:Corynebacterium diphtheriae']",
#  "['GTDB:Corynebacterium imitans']",
#  "['GTDB:Corynebacterium jeikeium']",
#  "['GTDB:Corynebacterium kroppenstedtii']",
#  "['GTDB:Corynebacterium macginleyi']",
#  "['GTDB:Corynebacterium matruchotii']",
#  "['GTDB:Corynebacterium mucifaciens']",
#  "['GTDB:Corynebacterium resistens']",
#  "['GTDB:Corynebacterium ulcerans']",
#  "['GTDB:Corynebacterium urealyticum']",
#  "['GTDB:Coxiella burnetii']",
#  "['GTDB:Cronobacter condimenti']",
#  "['GTDB:Cronobacter dublinensis']",
#  "['GTDB:Cronobacter malonaticus']",
#  "['GTDB:Cronobacter sakazakii']",
#  "['GTDB:Cronobacter turicensis']",
#  "['GTDB:Cronobacter universalis']",
#  "['GTDB:Cryptobacterium curtum']",
#  "['GTDB:Cutibacterium acnes']",
#  "['GTDB:Cutibacterium namnetense']",
#  "['GTDB:Desulfobulbus oralis']",
#  "['GTDB:Edwardsiella tarda']",
#  "['GTDB:Eggerthella lenta']",
#  "['GTDB:Ehrlichia chaffeensis']",
#  "['GTDB:Eikenella corrodens']",
#  "['GTDB:Elizabethkingia anophelis']",
#  "['GTDB:Elizabethkingia miricola']",
#  "['GTDB:Enterobacter cancerogenus']",
#  "['GTDB:Enterobacter cloacae']",
#  "['GTDB:Enterobacter hormaechei']",
#  "['GTDB:Enterobacter hormaechei_A']",
#  "['GTDB:Enterobacter ludwigii']",
#  "['GTDB:Enterobacter roggenkampii']",
#  "['GTDB:Enterococcus faecalis']",
#  "['GTDB:Enterococcus_A avium']",
#  "['GTDB:Enterococcus_A gilvus']",
#  "['GTDB:Enterococcus_A pallens']",
#  "['GTDB:Enterococcus_B faecium']",
#  "['GTDB:Enterococcus_B lactis']",
#  "['GTDB:Enterococcus_D casseliflavus']",
#  "['GTDB:Erysipelothrix rhusiopathiae']",
#  "['GTDB:Escherichia coli']",
#  "['GTDB:Escherichia fergusonii']",
#  "['GTDB:Escherichia ruysiae']",
#  "['GTDB:Finegoldia magna_H']",
#  "['GTDB:Flavobacterium odoratimimum']",
#  "['GTDB:Francisella tularensis']",
#  "['GTDB:Fusobacterium nucleatum']",
#  "['GTDB:Fusobacterium periodonticum']",
#  "['GTDB:Fusobacterium_A varium_A']",
#  "['GTDB:Fusobacterium_C necrophorum']",
#  "['GTDB:Gemella haemolysans_A']",
#  "['GTDB:Gemella morbillorum']",
#  "['GTDB:Gemella sanguinis']",
#  "['GTDB:Glutamicibacter creatinolyticus']",
#  "['GTDB:Gordonia bronchialis']",
#  "['GTDB:Granulibacter bethesdensis']",
#  "['GTDB:Haemophilus aegyptius']",
#  "['GTDB:Haemophilus influenzae']",
#  "['GTDB:Haemophilus influenzae_D']",
#  "['GTDB:Haemophilus influenzae_E']",
#  "['GTDB:Haemophilus influenzae_G']",
#  "['GTDB:Haemophilus_B ducreyi']",
#  "['GTDB:Hafnia alvei']",
#  "['GTDB:Helicobacter pylori']",
#  "['GTDB:Helicobacter pylori_A']",
#  "['GTDB:Helicobacter pylori_BU']",
#  "['GTDB:Helicobacter pylori_C']",
#  "['GTDB:Helicobacter pylori_CI']",
#  "['GTDB:Helicobacter_B fennelliae']",
#  "['GTDB:Helicobacter_C cinaedi']",
#  "['GTDB:Helicobacter_D canadensis']",
#  "['GTDB:Helicobacter_D pullorum']",
#  "['GTDB:Helicobacter_E heilmannii']",
#  "['GTDB:Helicobacter_E suis']",
#  "['GTDB:Inquilinus limosus_E']",
#  "['GTDB:Kerstersia gyiorum']",
#  "['GTDB:Kingella kingae']",
#  "['GTDB:Klebsiella aerogenes']",
#  "['GTDB:Klebsiella africana']",
#  "['GTDB:Klebsiella huaxiensis']",
#  "['GTDB:Klebsiella michiganensis']",
#  "['GTDB:Klebsiella pneumoniae']",
#  "['GTDB:Klebsiella quasipneumoniae']",
#  "['GTDB:Klebsiella terrigena']",
#  "['GTDB:Kosakonia cowanii']",
#  "['GTDB:Lactococcus garvieae']",
#  "['GTDB:Lancefieldella rimae']",
#  "['GTDB:Laribacter hongkongensis']",
#  "['GTDB:Legionella anisa']",
#  "['GTDB:Legionella longbeachae']",
#  "['GTDB:Legionella pneumophila']",
#  "['GTDB:Legionella sainthelensi']",
#  "['GTDB:Leptospira borgpetersenii']",
#  "['GTDB:Leptospira interrogans']",
#  "['GTDB:Leptospira kmetyi']",
#  "['GTDB:Leptospira santarosai']",
#  "['GTDB:Listeria monocytogenes']",
#  "['GTDB:Listeria monocytogenes_B']",
#  "['GTDB:Listeria monocytogenes_C']",
#  "['GTDB:Malacoplasma penetrans']",
#  "['GTDB:Mammaliicoccus lentus']",
#  "['GTDB:Metamycoplasma hominis']",
#  "['GTDB:Mobiluncus mulieris']",
#  "['GTDB:Moraxella catarrhalis']",
#  "['GTDB:Morganella morganii']",
#  "['GTDB:Mycobacterium abscessus']",
#  "['GTDB:Mycobacterium aichiense']",
#  "['GTDB:Mycobacterium algericum']",
#  "['GTDB:Mycobacterium alvei']",
#  "['GTDB:Mycobacterium aubagnense']",
#  "['GTDB:Mycobacterium avium']",
#  "['GTDB:Mycobacterium celeriflavum']",
#  "['GTDB:Mycobacterium chelonae']",
#  "['GTDB:Mycobacterium colombiense']",
#  "['GTDB:Mycobacterium doricum']",
#  "['GTDB:Mycobacterium duvalii']",
#  "['GTDB:Mycobacterium florentinum']",
#  "['GTDB:Mycobacterium fortuitum']",
#  "['GTDB:Mycobacterium gallinarum']",
#  "['GTDB:Mycobacterium grossiae']",
#  "['GTDB:Mycobacterium haemophilum']",
#  "['GTDB:Mycobacterium heckeshornense']",
#  "['GTDB:Mycobacterium insubricum']",
#  "['GTDB:Mycobacterium intracellulare']",
#  "['GTDB:Mycobacterium kansasii']",
#  "['GTDB:Mycobacterium koreense']",
#  "['GTDB:Mycobacterium leprae']",
#  "['GTDB:Mycobacterium lepromatosis']",
#  "['GTDB:Mycobacterium marinum']",
#  "['GTDB:Mycobacterium noviomagense']",
#  "['GTDB:Mycobacterium phocaicum']",
#  "['GTDB:Mycobacterium saopaulense']",
#  "['GTDB:Mycobacterium seoulense']",
#  "['GTDB:Mycobacterium septicum']",
#  "['GTDB:Mycobacterium shigaense']",
#  "['GTDB:Mycobacterium sp000328565']",
#  "['GTDB:Mycobacterium stomatepiae']",
#  "['GTDB:Mycobacterium tuberculosis']",
#  "['GTDB:Mycoplasmoides amphoriforme']",
#  "['GTDB:Mycoplasmoides genitalium']",
#  "['GTDB:Mycoplasmoides pneumoniae']",
#  "['GTDB:Mycoplasmopsis fermentans']",
#  "['GTDB:Neisseria brasiliensis']",
#  "['GTDB:Neisseria flavescens_A']",
#  "['GTDB:Neisseria flavescens_B']",
#  "['GTDB:Neisseria flavescens_C']",
#  "['GTDB:Neisseria gonorrhoeae']",
#  "['GTDB:Neisseria meningitidis']",
#  "['GTDB:Neisseria perflava']",
#  "['GTDB:Neorickettsia sennetsu']",
#  "['GTDB:Nocardia asiatica']",
#  "['GTDB:Nocardia brasiliensis_B']",
#  "['GTDB:Nocardia cyriacigeorgica_B']",
#  "['GTDB:Nocardia exalbida']",
#  "['GTDB:Nocardia farcinica']",
#  "['GTDB:Nocardia terpenica']",
#  "['GTDB:Nocardia wallacei']",
#  "['GTDB:Nocardiopsis dassonvillei']",
#  "['GTDB:Ochrobactrum anthropi']",
#  "['GTDB:Ochrobactrum intermedium']",
#  "['GTDB:Odoribacter splanchnicus']",
#  "['GTDB:Olsenella uli']",
#  "['GTDB:Oribacterium parvum']",
#  "['GTDB:Orientia tsutsugamushi']",
#  "['GTDB:Pandoraea apista']",
#  "['GTDB:Pandoraea fibrosis']",
#  "['GTDB:Pandoraea pnomenusa']",
#  "['GTDB:Pannonibacter indicus']",
#  "['GTDB:Pantoea ananatis']",
#  "['GTDB:Parabacteroides distasonis']",
#  "['GTDB:Paraclostridium sordellii']",
#  "['GTDB:Parascardovia denticolens']",
#  "['GTDB:Parasutterella excrementihominis']",
#  "['GTDB:Parvimonas micra']",
#  "['GTDB:Pasteurella multocida']",
#  "['GTDB:Pauljensenia odontolytica_A']",
#  "['GTDB:Pauljensenia odontolytica_C']",
#  "['GTDB:Peptidiphaga gingivicola']",
#  "['GTDB:Phocaeicola massiliensis']",
#  "['GTDB:Phocaeicola vulgatus']",
#  "['GTDB:Photorhabdus asymbiotica']",
#  "['GTDB:Plesiomonas shigelloides']",
#  "['GTDB:Porphyromonas gingivalis']",
#  "['GTDB:Prevotella bivia']",
#  "['GTDB:Prevotella intermedia']",
#  "['GTDB:Proteus mirabilis']",
#  "['GTDB:Proteus penneri']",
#  "['GTDB:Providencia alcalifaciens']",
#  "['GTDB:Providencia huaxiensis']",
#  "['GTDB:Providencia rettgeri_D']",
#  "['GTDB:Providencia_C stuartii']",
#  "['GTDB:Pseudoflavonifractor capillosus']",
#  "['GTDB:Pseudoleptotrichia goodfellowii']",
#  "['GTDB:Pseudomonas aeruginosa']",
#  "['GTDB:Pseudomonas aeruginosa_A']",
#  "['GTDB:Pseudomonas_E fluorescens_AP']",
#  "['GTDB:Pseudomonas_E haemolytica']",
#  "['GTDB:Pseudomonas_E iridis']",
#  "['GTDB:Pseudomonas_E lactis']",
#  "['GTDB:Pseudomonas_E lundensis']",
#  "['GTDB:Pseudomonas_E lurida']",
#  "['GTDB:Pseudomonas_E paracarnis']",
#  "['GTDB:Pseudomonas_E parakoreensis']",
#  "['GTDB:Pseudomonas_E protegens']",
#  "['GTDB:Pseudomonas_E putida']",
#  "['GTDB:Pseudomonas_E rhodesiae']",
#  "['GTDB:Rhodococcus equi']",
#  "['GTDB:Rhodococcus gordoniae']",
#  "['GTDB:Rickettsia akari']",
#  "['GTDB:Rickettsia felis']",
#  "['GTDB:Rickettsia prowazekii']",
#  "['GTDB:Rickettsia rhipicephali']",
#  "['GTDB:Rickettsia rickettsii']",
#  "['GTDB:Rickettsia typhi']",
#  "['GTDB:Rothia aeria']",
#  "['GTDB:Rothia mucilaginosa_B']",
#  "['GTDB:Rothia sp001808955']",
#  "['GTDB:Saccharomonospora viridis']",
#  "['GTDB:Salmonella arizonae']",
#  "['GTDB:Salmonella enterica']",
#  "['GTDB:Sarcina perfringens']",
#  "['GTDB:Serratia marcescens_K']",
#  "['GTDB:Shewanella xiamenensis']",
#  "['GTDB:Simkania negevensis']",
#  "['GTDB:Sneathia vaginalis']",
#  "['GTDB:Staphylococcus arlettae']",
#  "['GTDB:Staphylococcus aureus']",
#  "['GTDB:Staphylococcus capitis']",
#  "['GTDB:Staphylococcus epidermidis']",
#  "['GTDB:Staphylococcus haemolyticus']",
#  "['GTDB:Staphylococcus lugdunensis']",
#  "['GTDB:Staphylococcus massiliensis']",
#  "['GTDB:Staphylococcus saprophyticus']",
#  "['GTDB:Staphylococcus warneri']",
#  "['GTDB:Stenotrophomonas maltophilia']",
#  "['GTDB:Stenotrophomonas maltophilia_F']",
#  "['GTDB:Streptobacillus moniliformis']",
#  "['GTDB:Streptococcus agalactiae']",
#  "['GTDB:Streptococcus anginosus']",
#  "['GTDB:Streptococcus anginosus_C']",
#  "['GTDB:Streptococcus constellatus']",
#  "['GTDB:Streptococcus dysgalactiae']",
#  "['GTDB:Streptococcus equi']",
#  "['GTDB:Streptococcus gallolyticus']",
#  "['GTDB:Streptococcus gordonii']",
#  "['GTDB:Streptococcus ilei']",
#  "['GTDB:Streptococcus infantis_I']",
#  "['GTDB:Streptococcus iniae']",
#  "['GTDB:Streptococcus intermedius']",
#  "['GTDB:Streptococcus mitis_M']",
#  "['GTDB:Streptococcus mitis_O']",
#  "['GTDB:Streptococcus mitis_Q']",
#  "['GTDB:Streptococcus mutans']",
#  "['GTDB:Streptococcus oralis_BC']",
#  "['GTDB:Streptococcus oriscaviae']",
#  "['GTDB:Streptococcus parasanguinis']",
#  "['GTDB:Streptococcus pneumoniae']",
#  "['GTDB:Streptococcus pseudopneumoniae']",
#  "['GTDB:Streptococcus pyogenes']",
#  "['GTDB:Streptococcus salivarius']",
#  "['GTDB:Streptococcus sanguinis']",
#  "['GTDB:Streptococcus sanguinis_H']",
#  "['GTDB:Streptococcus sobrinus']",
#  "['GTDB:Streptococcus sp002355895']",
#  "['GTDB:Streptococcus suis']",
#  "['GTDB:Streptococcus symci']",
#  "['GTDB:Streptococcus urinalis']",
#  "['GTDB:Tannerella forsythia']",
#  "['GTDB:Thomasclavelia spiroformis']",
#  "['GTDB:Treponema pallidum']",
#  "['GTDB:Treponema sp000775995']",
#  "['GTDB:Treponema sp010365865']",
#  "['GTDB:Treponema_B denticola']",
#  "['GTDB:Treponema_B putidum']",
#  "['GTDB:Tropheryma whipplei']",
#  "['GTDB:Tsukamurella paurometabola']",
#  "['GTDB:Tsukamurella tyrosinosolvens']",
#  "['GTDB:Ureaplasma parvum']",
#  "['GTDB:Ureaplasma urealyticum']",
#  "['GTDB:Vibrio alginolyticus']",
#  "['GTDB:Vibrio cholerae']",
#  "['GTDB:Vibrio furnissii']",
#  "['GTDB:Vibrio harveyi']",
#  "['GTDB:Vibrio mimicus']",
#  "['GTDB:Vibrio owensii']",
#  "['GTDB:Vibrio parahaemolyticus']",
#  "['GTDB:Vibrio vulnificus']",
#  "['GTDB:Yersinia enterocolitica']",
#  "['GTDB:Yersinia kristensenii']",
#  "['GTDB:Yersinia pestis']"}

# %%
gtdbid_df.loc[gtdbid_df['gtdb_id'].isin(all_potential_pathogenic_strain),:].reset_index(drop=True).to_csv(os.path.join(args.output_dir, 'all_potential_pathogenic_strain.tsv'), sep='\t', index=False)

# %%
edge_info.to_csv(os.path.join(args.output_dir, 'edge_info.tsv'), sep='\t', index=False)

# %%
set_seed(100)
species1_list = list(species1)
random.shuffle(species1_list)
hold_out_species = species1_list[:int(len(species1_list)*0.1)]

# %%
pathogen_info.loc[pathogen_info['parent_list'].isin(hold_out_species),:].to_csv(os.path.join(args.output_dir, 'hold_out_pathogen_info.tsv'), sep='\t', index=False)
